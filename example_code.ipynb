# %%
#This celll initializes the data for the transcript and the segments of the story

segments = ['Hensel and Gretel are a brother and sister',
 'who get lost in a deep forest.',
 'They find a house made of candy and start',
 'eating it.',
 'But a wicked witch lives inside and captures',
 'them, planning to eat them.',
 'The clever children outsmart the witch by',
 'tricking her into the oven, where she is',
 'burned.',
 'They escape, find their way back home and',
 "discover the witch's treasure.",
 'With this, they live happily ever after with',
 'their father, who is overjoyed to see them',
 'safe.']

from typing import List, Optional

class Word:
    def __init__(self, text: str, start: int, end: int, confidence: float, speaker: Optional[str] = None):
        self.text = text
        self.start = start
        self.end = end
        self.confidence = confidence
        self.speaker = speaker

    def __repr__(self):
        return (f"Word(text='{self.text}', start={self.start}, end={self.end}, "
                f"confidence={self.confidence}, speaker={self.speaker})")

class Transcript:
    def __init__(self, words: List[Word]):
        self.words = words

    def __repr__(self):
        return f"Transcript(words={self.words})"

# Example usage
transcript = Transcript(words=[
    Word(text='Hensel', start=160, end=488, confidence=0.69857, speaker=None),
 Word(text='and', start=494, end=662, confidence=1.0, speaker=None),
 Word(text='Gretel', start=686, end=1166, confidence=0.29617, speaker=None),
 Word(text='are', start=1238, end=1422, confidence=0.99982, speaker=None),
 Word(text='a', start=1446, end=1582, confidence=1.0, speaker=None),
 Word(text='brother', start=1606, end=1870, confidence=0.99984, speaker=None),
 Word(text='and', start=1910, end=2110, confidence=1.0, speaker=None),
 Word(text='sister', start=2150, end=2518, confidence=0.93801, speaker=None),
 Word(text='who', start=2614, end=2822, confidence=0.99966, speaker=None),
 Word(text='get', start=2846, end=3030, confidence=0.99927, speaker=None),
 Word(text='lost', start=3070, end=3342, confidence=0.99986, speaker=None),
 Word(text='in', start=3406, end=3558, confidence=0.99976, speaker=None),
 Word(text='a', start=3574, end=3702, confidence=1.0, speaker=None),
 Word(text='deep', start=3726, end=3950, confidence=0.99988, speaker=None),
 Word(text='forest.', start=3990, end=4734, confidence=0.99932, speaker=None),
 Word(text='They', start=4902, end=5182, confidence=0.99908, speaker=None),
 Word(text='find', start=5206, end=5366, confidence=0.99975, speaker=None),
 Word(text='a', start=5398, end=5542, confidence=1.0, speaker=None),
 Word(text='house', start=5566, end=5774, confidence=0.99997, speaker=None),
 Word(text='made', start=5822, end=5958, confidence=0.99948, speaker=None),
 Word(text='of', start=5974, end=6102, confidence=1.0, speaker=None),
 Word(text='candy', start=6126, end=6558, confidence=0.8947, speaker=None),
 Word(text='and', start=6614, end=6830, confidence=1.0, speaker=None),
 Word(text='start', start=6870, end=7094, confidence=0.99953, speaker=None),
 Word(text='eating', start=7142, end=7374, confidence=0.86113, speaker=None),
 Word(text='it.', start=7422, end=7822, confidence=0.9992, speaker=None),
 Word(text='But', start=7926, end=8118, confidence=0.99912, speaker=None),
 Word(text='a', start=8134, end=8238, confidence=1.0, speaker=None),
 Word(text='wicked', start=8254, end=8526, confidence=0.52719, speaker=None),
 Word(text='witch', start=8558, end=8934, confidence=0.57758, speaker=None),
 Word(text='lives', start=9022, end=9318, confidence=0.99982, speaker=None),
 Word(text='inside', start=9374, end=9718, confidence=0.61871, speaker=None),
 Word(text='and', start=9774, end=9966, confidence=1.0, speaker=None),
 Word(text='captures', start=9998, end=10438, confidence=0.56969, speaker=None),
 Word(text='them,', start=10494, end=10902, confidence=0.99987, speaker=None),
 Word(text='planning', start=11006, end=11406, confidence=0.99925, speaker=None),
 Word(text='to', start=11438, end=11582, confidence=1.0, speaker=None),
 Word(text='eat', start=11606, end=11790, confidence=0.99195, speaker=None),
 Word(text='them.', start=11830, end=12390, confidence=0.99977, speaker=None),
 Word(text='The', start=12550, end=12822, confidence=1.0, speaker=None),
 Word(text='clever', start=12846, end=13134, confidence=0.99975, speaker=None),
 Word(text='children', start=13182, end=13462, confidence=0.99993, speaker=None),
 Word(text='outsmart', start=13526, end=14046, confidence=0.81733, speaker=None),
 Word(text='the', start=14078, end=14198, confidence=1.0, speaker=None),
 Word(text='witch', start=14214, end=14454, confidence=0.9955, speaker=None),
 Word(text='by', start=14502, end=14686, confidence=0.99994, speaker=None),
 Word(text='tricking', start=14718, end=15070, confidence=0.99953, speaker=None),
 Word(text='her', start=15110, end=15286, confidence=0.99995, speaker=None),
 Word(text='into', start=15318, end=15486, confidence=0.99962, speaker=None),
 Word(text='the', start=15518, end=15662, confidence=1.0, speaker=None),
 Word(text='oven,', start=15686, end=16038, confidence=0.99982, speaker=None),
 Word(text='where', start=16134, end=16366, confidence=0.99947, speaker=None),
 Word(text='she', start=16398, end=16518, confidence=0.99992, speaker=None),
 Word(text='is', start=16534, end=16710, confidence=0.6942, speaker=None),
 Word(text='burned.', start=16750, end=17410, confidence=0.976, speaker=None),
 Word(text='They', start=17710, end=18046, confidence=0.99912, speaker=None),
 Word(text='escape,', start=18078, end=18742, confidence=0.97854, speaker=None),
 Word(text='find', start=18886, end=19190, confidence=0.99988, speaker=None),
 Word(text='their', start=19230, end=19406, confidence=0.99986, speaker=None),
 Word(text='way', start=19438, end=19606, confidence=0.99996, speaker=None),
 Word(text='back', start=19638, end=19830, confidence=0.99925, speaker=None),
 Word(text='home', start=19870, end=20334, confidence=0.99994, speaker=None),
 Word(text='and', start=20462, end=20750, confidence=1.0, speaker=None),
 Word(text='discover', start=20790, end=21134, confidence=0.99541, speaker=None),
 Word(text='the', start=21182, end=21342, confidence=1.0, speaker=None),
 Word(text="witch's", start=21366, end=21774, confidence=0.61476, speaker=None),
 Word(text='treasure.', start=21822, end=22606, confidence=0.76861, speaker=None),
 Word(text='With', start=22798, end=23126, confidence=0.9998, speaker=None),
 Word(text='this,', start=23158, end=23470, confidence=0.99994, speaker=None),
 Word(text='they', start=23550, end=23742, confidence=0.99984, speaker=None),
 Word(text='live', start=23766, end=23950, confidence=0.99985, speaker=None),
 Word(text='happily', start=23990, end=24294, confidence=0.72448, speaker=None),
 Word(text='ever', start=24342, end=24574, confidence=0.99995, speaker=None),
 Word(text='after', start=24622, end=24902, confidence=0.99945, speaker=None),
 Word(text='with', start=24966, end=25142, confidence=0.9997, speaker=None),
 Word(text='their', start=25166, end=25326, confidence=0.9997, speaker=None),
 Word(text='father,', start=25358, end=25758, confidence=0.99966, speaker=None),
 Word(text='who', start=25854, end=26038, confidence=0.99985, speaker=None),
 Word(text='is', start=26054, end=26206, confidence=0.99569, speaker=None),
 Word(text='overjoyed', start=26238, end=26758, confidence=0.91897, speaker=None),
 Word(text='to', start=26774, end=26902, confidence=1.0, speaker=None),
 Word(text='see', start=26926, end=27062, confidence=0.99984, speaker=None),
 Word(text='them', start=27086, end=27270, confidence=0.99977, speaker=None),
 Word(text='safe.', start=27310, end=27510, confidence=0.9994, speaker=None)
    # Add other Word instances here
])

print(transcript)
# Out:
# Transcript(words=[Word(text='Hensel', start=160, end=488, confidence=0.69857, speaker=None), Word(text='and', start=494, end=662, confidence=1.0, speaker=None), Word(text='Gretel', start=686, end=1166, confidence=0.29617, speaker=None), Word(text='are', start=1238, end=1422, confidence=0.99982, speaker=None), Word(text='a', start=1446, end=1582, confidence=1.0, speaker=None), Word(text='brother', start=1606, end=1870, confidence=0.99984, speaker=None), Word(text='and', start=1910, end=2110, confidence=1.0, speaker=None), Word(text='sister', start=2150, end=2518, confidence=0.93801, speaker=None), Word(text='who', start=2614, end=2822, confidence=0.99966, speaker=None), Word(text='get', start=2846, end=3030, confidence=0.99927, speaker=None), Word(text='lost', start=3070, end=3342, confidence=0.99986, speaker=None), Word(text='in', start=3406, end=3558, confidence=0.99976, speaker=None), Word(text='a', start=3574, end=3702, confidence=1.0, speaker=None), Word(text='deep', start=3726, 
# ...
